# %%
from PIL import Image
import numpy as np
import sys
import os
import csv

# default format can be changed as needed
def createFileList(myDir, format='.jpg'):
    fileList = []
    print(myDir)
    for root, dirs, files in os.walk(myDir, topdown=False):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
    return fileList

# load the original image
myFileList = createFileList('../keras/grayscale')

for file in myFileList:
    print(file)
    img_file = Image.open(file)
    # img_file.show()

    # get original image parameters...
    width, height = img_file.size
    format = img_file.format
    mode = img_file.mode

    # Make image Greyscale
    img_grey = img_file.convert('L')
    #img_grey.save('result.png')
    #img_grey.show()

    # Save Greyscale values
    value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
    value = value.flatten()
    print(value)
    with open("KidneyDataset.csv", 'a',newline='') as f:
        writer = csv.writer(f)
        writer.writerow(value)
# Out:
# ../keras/grayscale
# ../keras/grayscale\healthy\altmisdokuz_resized.jpg
# [ 0  3  4 ... 38 31 20]
# ../keras/grayscale\healthy\altmisdort_resized.jpg
# [ 0  2  4 ... 40 38 45]
# ../keras/grayscale\healthy\elliiki_resized.jpg
# [ 3  1  6 ... 53 48 10]
# ../keras/grayscale\healthy\elliuc_resized.jpg
# [ 0  2  2 ... 21 20 19]
# ../keras/grayscale\healthy\elliyedi_resized.jpg
# [103 122 142 ...   9   9   1]
# ../keras/grayscale\healthy\kirkdokuz_resized.jpg
# [ 1  2  4 ... 75 68 51]
# ../keras/grayscale\healthy\kirkuc_resized.jpg
# [ 9 20 25 ... 89 62 54]
# ../keras/grayscale\healthy\onyedi_resized.jpg
# [60 64 57 ... 23 24 25]
# ../keras/grayscale\healthy\on_resized.jpg
# [ 1  5 13 ... 43 24 16]
# ../keras/grayscale\healthy\otuzsekiz_resized.jpg
# [38 50 50 ...  4  0  0]
# ../keras/grayscale\healthy\sekiz_resized.jpg
# [ 90 104 120 ...   3   2   5]
# ../keras/grayscale\patient\alti_resized.jpg
# [208 211 213 ...  20  13   6]
# ../keras/grayscale\patient\altmisalti_resized.jpg
# [ 4  4  4 ...  9  9 12]
# ../keras/grayscale\patient\altmisbes_resized.jpg
# [31 26 20 ... 13 13 12]
# ../keras/grayscale\patient\altmisbir_resized.jpg
# [  0   1   2 ... 106  76  50]
# ../keras/grayscale\patient\altmisiki_resized.jpg
# [ 50  43  34 ... 146 145 110]
# ../keras/grayscale\patient\altmissekiz_resized.jpg
# [ 5 10 17 ... 36 22 12]
# ../keras/grayscale\patient\altmisuc_resized.jpg
# [ 0  0  1 ... 85 85 34]
# ../keras/grayscale\patient\altmisyedi_resized.jpg
# [ 0  3 10 ...  2  5  1]
# ../keras/grayscale\patient\altmis_resized.jpg
# [10  0 21 ...  3  3  3]
# ../keras/grayscale\patient\bes_resized.jpg
# [126 135 144 ...  72  58  52]
# ../keras/grayscale\patient\ellialti_resized.jpg
# [  0   6   5 ... 142 111  63]
# ../keras/grayscale\patient\ellibes_resized.jpg
# [140 160 172 ...  41  26   0]
# ../keras/grayscale\patient\ellibir_resized.jpg
# [ 21  50  74 ... 162 116   7]
# ../keras/grayscale\patient\ellidokuz_resized.jpg
# [ 9 16 33 ...  6  6  6]
# ../keras/grayscale\patient\ellidort_resized.jpg
# [  0   1  27 ... 192 177 161]
# ../keras/grayscale\patient\ellisekiz_resized.jpg
# [ 0  0  2 ... 86 60 46]
# ../keras/grayscale\patient\elli_resized.jpg
# [ 0  3  6 ... 27  8  1]
# ../keras/grayscale\patient\kirkalti_resized.jpg
# [  4   5   8 ... 156 139 122]
# ../keras/grayscale\patient\kirkbes_resized.jpg
# [148 232 227 ... 132 125 122]
# ../keras/grayscale\patient\kirkbir_resized.jpg
# [ 77 134 171 ...  69  48  17]
# ../keras/grayscale\patient\kirkdort_resized.jpg
# [ 85 113 125 ... 169 163 156]
# ../keras/grayscale\patient\kirkiki_resized.jpg
# [ 95 119 134 ... 134  77   0]
# ../keras/grayscale\patient\kirksekiz_resized.jpg
# [ 5 30 74 ... 78 63 48]
# ../keras/grayscale\patient\kirkyedi_resized.jpg
# [8 8 8 ... 4 4 4]
# ../keras/grayscale\patient\kirk_resized.jpg
# [ 31  46  60 ... 134 127 122]
# ../keras/grayscale\patient\onalti_resized.jpg
# [21 21 21 ... 96 74 56]
# ../keras/grayscale\patient\onbes_resized.jpg
# [17 17 17 ...  7  2  4]
# ../keras/grayscale\patient\onbir_resized.jpg
# [12 17 18 ... 29  9  6]
# ../keras/grayscale\patient\ondokuz_resized.jpg
# [11 29 41 ... 22 14  7]
# ../keras/grayscale\patient\ondort_resized.jpg
# [28 28 27 ...  0  0  0]
# ../keras/grayscale\patient\oniki_resized.jpg
# [12 16 19 ... 27 14  6]
# ../keras/grayscale\patient\onsekiz_resized.jpg
# [ 9 20 38 ... 85 89 62]
# ../keras/grayscale\patient\onuc_resized.jpg
# [36 35 20 ...  6  5  5]
# ../keras/grayscale\patient\otuzalti_resized.jpg
# [122 159 188 ...  62  74  50]
# ../keras/grayscale\patient\otuzbes_resized.jpg
# [50 50 52 ... 39 24  6]
# ../keras/grayscale\patient\otuzbir_resized.jpg
# [137 145 160 ... 151  99  37]
# ../keras/grayscale\patient\otuzdokuz_resized.jpg
# [ 1  8 40 ... 65 48 23]
# ../keras/grayscale\patient\otuzdort_resized.jpg
# [202 132 138 ...  90  75  78]
# ../keras/grayscale\patient\otuziki_resized.jpg
# [196 203 206 ...  45  32  16]
# ../keras/grayscale\patient\otuzuc_resized.jpg
# [138 150 156 ... 124  92  95]
# ../keras/grayscale\patient\otuzyedi_resized.jpg
# [  2   1   0 ... 104  30   0]
# ../keras/grayscale\patient\otuz_resized.jpg
# [219 209 193 ... 148 131 182]
# ../keras/grayscale\patient\seksenalti_resized.jpg
# [ 0 22  0 ... 17 44 71]
# ../keras/grayscale\patient\seksenbes_resized.jpg
# [ 7  0  2 ... 66 32 15]
# ../keras/grayscale\patient\seksenbir_resized.jpg
# [161 182 191 ...  34  17  10]
# ../keras/grayscale\patient\seksendort_resized.jpg
# [  0   6   2 ... 156 159 167]
# ../keras/grayscale\patient\sekseniki_resized.jpg
# [ 22  38 146 ... 153 131  97]
# ../keras/grayscale\patient\seksenuc_resized.jpg
# [215 176 154 ... 101  74  58]
# ../keras/grayscale\patient\seksenyedi_resized.jpg
# [ 10  74 133 ... 117 126 108]
# ../keras/grayscale\patient\seksen_resized.jpg
# [ 7 16 26 ...  0  0  1]
# ../keras/grayscale\patient\uc_resized.jpg
# [  0   0   9 ... 148 132 120]
# ../keras/grayscale\patient\yedi_resized.jpg
# [156 168 178 ... 161 159 160]
# ../keras/grayscale\patient\yetmisalti_resized.jpg
# [29 54 86 ... 65 31 27]
# ../keras/grayscale\patient\yetmisbes_resized.jpg
# [174 197 202 ... 132 139  36]
# ../keras/grayscale\patient\yetmisbir_resized.jpg
# [  2   2   1 ... 134 124  26]
# ../keras/grayscale\patient\yetmisdokuz_resized.jpg
# [6 0 2 ... 0 1 2]
# ../keras/grayscale\patient\yetmisdort_resized.jpg
# [21 56 10 ... 20  9  0]
# ../keras/grayscale\patient\yetmisiki_resized.jpg
# [  0   3  61 ... 182 146  70]
# ../keras/grayscale\patient\yetmissekiz_resized.jpg
# [1 1 1 ... 1 6 2]
# ../keras/grayscale\patient\yetmisuc_resized.jpg
# [ 75 131 176 ...  42  22   0]
# ../keras/grayscale\patient\yetmisyedi_resized.jpg
# [  2   0   0 ... 115 106 129]
# ../keras/grayscale\patient\yetmis_resized.jpg
# [177 137 157 ...  74  49  42]
# ../keras/grayscale\patient\yirmialti_resized.jpg
# [ 73 101 120 ...  42  31  27]
# ../keras/grayscale\patient\yirmibes_resized.jpg
# [28 32 35 ... 92 77 65]
# ../keras/grayscale\patient\yirmibir_resized.jpg
# [ 1 32 77 ...  3  1  0]
# ../keras/grayscale\patient\yirmidokuz_resized.jpg
# [55 63 68 ... 75 50 41]
# ../keras/grayscale\patient\yirmidort_resized.jpg
# [34 53 78 ... 91 41 17]
# ../keras/grayscale\patient\yirmiiki_resized.jpg
# [ 2  2 22 ... 80 80 64]
# ../keras/grayscale\patient\yirmisekiz_resized.jpg
# [  8  63 150 ...  61  28  29]
# ../keras/grayscale\patient\yirmiuc_resized.jpg
# [174  89 124 ... 190 188 189]
# ../keras/grayscale\patient\yirmiyedi_resized.jpg
# [ 13  25  35 ... 121 112  93]
# ../keras/grayscale\patient\yirmi_resized.jpg
# [ 7  2 27 ... 50 66 49]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-631968201b4e> in <module>
#       3
#       4 # Create a graph for training
# ----> 5 logits_train = conv_net(X, N_CLASSES, dropout, reuse=False, is_training=True)
#       6 # Create another graph for testing that reuse the same weights
#       7 logits_test = conv_net(X, N_CLASSES, dropout, reuse=True, is_training=False)
#
# <ipython-input-92-659b8734abf1> in conv_net(x, n_classes, dropout, reuse, is_training)
#       5
#       6         # Convolution Layer with 32 filters and a kernel size of 5
# ----> 7         conv1 = tf.compat.v1.layers.conv2d(x, 32, 5, activation=tf.nn.relu)
#       8         # Max Pooling (down-sampling) with strides of 2 and kernel size of 2
#       9         conv1 = tf.layers.max_pooling2d(conv1, 2, 2)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\convolutional.py in conv2d(inputs, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, trainable, name, reuse)
#     422       _reuse=reuse,
#     423       _scope=name)
# --> 424   return layer.apply(inputs)
#     425
#     426
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py in apply(self, inputs, *args, **kwargs)
#    1699       Output tensor(s).
#    1700     """
# -> 1701     return self.__call__(inputs, *args, **kwargs)
#    1702
#    1703   @deprecation.deprecated(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\base.py in __call__(self, inputs, *args, **kwargs)
#     545
#     546       # Actually call layer
# --> 547       outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#     548
#     549     if not context.executing_eagerly():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py in __call__(self, *args, **kwargs)
#     755           # Build layer if applicable (if the `build` method has been
#     756           # overridden).
# --> 757           self._maybe_build(inputs)
#     758           cast_inputs = self._maybe_cast_inputs(inputs)
#     759
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py in _maybe_build(self, inputs)
#    2096         # operations.
#    2097         with tf_utils.maybe_init_scope(self):
# -> 2098           self.build(input_shapes)
#    2099       # We must set self.built since user defined build functions are not
#    2100       # constrained to set self.built.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\convolutional.py in build(self, input_shape)
#     195                                        self.filters)
#     196
# --> 197     self.kernel = self.add_weight(
#     198         name='kernel',
#     199         shape=kernel_shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\base.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, partitioner, **kwargs)
#     446         if initializer is None:
#     447           initializer = scope.initializer
# --> 448         variable = super(Layer, self).add_weight(
#     449             name,
#     450             shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     429         caching_device = None
#     430
# --> 431     variable = self._add_variable_with_custom_getter(
#     432         name=name,
#     433         shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     743         initializer = checkpoint_initializer
#     744         shape = None
# --> 745     new_variable = getter(
#     746         name=name,
#     747         shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1554                  synchronization=VariableSynchronization.AUTO,
#    1555                  aggregation=VariableAggregation.NONE):
# -> 1556   return get_variable_scope().get_variable(
#    1557       _get_default_variable_store(),
#    1558       name,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1297       if dtype is None:
#    1298         dtype = self._dtype
# -> 1299       return var_store.get_variable(
#    1300           full_name,
#    1301           shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#     552       return custom_getter(**custom_getter_kwargs)
#     553     else:
# --> 554       return _true_getter(
#     555           name,
#     556           shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint, synchronization, aggregation)
#     505             "name was already created with partitioning?" % name)
#     506
# --> 507       return self._get_single_variable(
#     508           name=name,
#     509           shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint, synchronization, aggregation)
#     868         # default case.
#     869         tb = [x for x in tb if "tensorflow/python" not in x[0]][:5]
# --> 870         raise ValueError("%s Originally defined at:\n\n%s" %
#     871                          (err_msg, "".join(traceback.format_list(tb))))
#     872       found_var = self._vars[name]
#
# ValueError: Variable ConvNet/conv2d/kernel already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1949, in __init__
#     self._traceback = tf_stack.extract_stack()
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3477, in _create_op_internal
#     ret = Operation(
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 742, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\ops\gen_state_ops.py", line 1752, in variable_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\ops\state_ops.py", line 74, in variable_op_v2
#     return gen_state_ops.variable_v2(
