# %%
from PIL import Image
import numpy as np
import sys
import os
import csv

# default format can be changed as needed
def createFileList(myDir, format='.jpg'):
    fileList = []
    print(myDir)
    for root, dirs, files in os.walk(myDir, topdown=False):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
    return fileList

# load the original image
myFileList = createFileList('../keras/deneme/patient_file') 

for file in myFileList:
    print(file)
    img_file = Image.open(file)
    # img_file.show()

    # get original image parameters...
    width, height = img_file.size
    format = img_file.format
    mode = img_file.mode

    # Make image Greyscale
    img_grey = img_file.convert('L')
    #img_grey.save('result.png')
    #img_grey.show()

    # Save Greyscale values
    value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
    value = value.flatten()
    print(value)
    with open("KidneyDataset.csv", 'a',newline='') as f:
        writer = csv.writer(f)
        writer.writerow(value)
# Out:
# ../keras/deneme/patient_file
# ../keras/deneme/patient_file\1677-6119-ibju-45-01-0187-gf01_resized_resized.jpg
# [24 17 24 ... 55 32 41]
# ../keras/deneme/patient_file\220px-DoubleJ_resized_resized.jpg
# [233  78  77 ... 107 106 107]
# ../keras/deneme/patient_file\4278196_c89acd8c9c_b_resized_resized.jpg
# [ 87  94 110 ...  38  19  18]
# ../keras/deneme/patient_file\4678aabdc62f49518d21058d737489bc_resized_resized.jpg
# [ 49  69  75 ... 121 116  92]
# ../keras/deneme/patient_file\a76b6ccbbad41ce47f83f5878f53085e-F_G_R2_resized_resized.jpg
# [137 141 183 ... 171 160 144]
# ../keras/deneme/patient_file\alti_resized_resized.jpg
# [208 211 213 ...  19  13   4]
# ../keras/deneme/patient_file\altmisalti_resized_resized.jpg
# [ 4  4  4 ... 10 10  9]
# ../keras/deneme/patient_file\altmisbes_resized_resized.jpg
# [30 25 19 ... 13 13 12]
# ../keras/deneme/patient_file\altmisbir_resized_resized.jpg
# [  0   0   0 ... 106  76  49]
# ../keras/deneme/patient_file\altmisdokuz_resized_resized.jpg
# [ 0  4  1 ... 40 32 16]
# ../keras/deneme/patient_file\altmisdort_resized_resized.jpg
# [ 0  1  4 ... 40 39 45]
# ../keras/deneme/patient_file\altmisiki_resized_resized.jpg
# [ 54  40  30 ... 145 148 108]
# ../keras/deneme/patient_file\altmissekiz_resized_resized.jpg
# [ 6  4 24 ... 36 22 12]
# ../keras/deneme/patient_file\altmisuc_resized_resized.jpg
# [ 0  0  1 ... 85 85 34]
# ../keras/deneme/patient_file\altmisyedi_resized_resized.jpg
# [ 0  2 10 ...  2  5  1]
# ../keras/deneme/patient_file\altmis_resized_resized.jpg
# [10  0 21 ...  3  3  3]
# ../keras/deneme/patient_file\b1fefcfa0e627c9c9be352314c58f5_jumbo_resized_resized.jpg
# [30 30 49 ... 66 49 28]
# ../keras/deneme/patient_file\b32b32a6c72101d389f19da072e20a_gallery_resized_resized.jpg
# [148 175 167 ...  91  81 115]
# ../keras/deneme/patient_file\bes_resized_resized.jpg
# [122 135 147 ...  72  58  52]
# ../keras/deneme/patient_file\e6e738ca8405ac5d7c488f0d40928c_jumbo_resized_resized.jpg
# [18 17 20 ... 31 31 29]
# ../keras/deneme/patient_file\ellialti_resized_resized.jpg
# [  0   9   6 ... 142 112  63]
# ../keras/deneme/patient_file\ellibes_resized_resized.jpg
# [139 160 171 ...  35  27   8]
# ../keras/deneme/patient_file\ellibir_resized_resized.jpg
# [ 24  52  75 ... 163 118   8]
# ../keras/deneme/patient_file\ellidokuz_resized_resized.jpg
# [11 18 36 ...  7  7  7]
# ../keras/deneme/patient_file\ellidort_resized_resized.jpg
# [  5   2  20 ... 193 180 166]
# ../keras/deneme/patient_file\elliiki_resized_resized.jpg
# [ 2  0 11 ... 53 48 10]
# ../keras/deneme/patient_file\ellisekiz_resized_resized.jpg
# [ 0  0  0 ... 86 60 46]
# ../keras/deneme/patient_file\elliuc_resized_resized.jpg
# [ 0  3  5 ... 21 21 20]
# ../keras/deneme/patient_file\elliyedi_resized_resized.jpg
# [103 122 142 ...  11  12   0]
# ../keras/deneme/patient_file\elli_resized_resized.jpg
# [ 0  2  5 ... 27  8  2]
# ../keras/deneme/patient_file\h46_resized_resized.jpg
# [  7   0  34 ... 117 111 110]
# ../keras/deneme/patient_file\h59_resized_resized.jpg
# [69 19 13 ... 59 27 26]
# ../keras/deneme/patient_file\hkirkdokuz_resized_resized.jpg
# [ 1  3  4 ... 72 65 47]
# ../keras/deneme/patient_file\image 1_resized_resized.jpg
# [ 4  4 23 ... 32 18  0]
# ../keras/deneme/patient_file\images (1)_resized_resized.jpg
# [219 242 235 ... 237 230 216]
# ../keras/deneme/patient_file\images (3)_resized_resized.jpg
# [11  0 23 ... 59 59 71]
# ../keras/deneme/patient_file\images 3_resized_resized.jpg
# [  0   6   0 ... 142 145 154]
# ../keras/deneme/patient_file\images_resized_resized.jpg
# [ 81 107 108 ... 170 173 123]
# ../keras/deneme/patient_file\img_resized_resized.jpg
# [ 99 104 116 ... 232 231 229]
# ../keras/deneme/patient_file\Kidney-Stone-X-Ray-002_resized_resized.jpg
# [ 60  28  61 ... 162 146 134]
# ../keras/deneme/patient_file\kirkalti_resized_resized.jpg
# [  0   0   4 ... 154 138 125]
# ../keras/deneme/patient_file\kirkbes_resized_resized.jpg
# [148 233 228 ... 132 124 121]
# ../keras/deneme/patient_file\kirkbir_resized_resized.jpg
# [ 78 135 171 ...  69  49  19]
# ../keras/deneme/patient_file\kirkdokuz_resized_resized.jpg
# [ 1  3  4 ... 72 65 47]
# ../keras/deneme/patient_file\kirkdort_resized_resized.jpg
# [ 86 114 126 ... 169 163 156]
# ../keras/deneme/patient_file\kirkiki_resized_resized.jpg
# [ 95 119 134 ... 135  78   1]
# ../keras/deneme/patient_file\kirksekiz_resized_resized.jpg
# [ 5 31 74 ... 78 63 48]
# ../keras/deneme/patient_file\kirkuc_resized_resized.jpg
# [ 6 21 28 ... 89 62 53]
# ../keras/deneme/patient_file\kirkyedi_resized_resized.jpg
# [8 8 8 ... 3 3 3]
# ../keras/deneme/patient_file\kirk_resized_resized.jpg
# [ 33  48  63 ... 139 129 123]
# ../keras/deneme/patient_file\onalti_resized_resized.jpg
# [21 21 21 ... 95 73 55]
# ../keras/deneme/patient_file\onbes_resized_resized.jpg
# [15 15 15 ...  7  1  4]
# ../keras/deneme/patient_file\onbir_resized_resized.jpg
# [13 18 19 ... 30 10  7]
# ../keras/deneme/patient_file\ondokuz_resized_resized.jpg
# [12 30 42 ... 21 13  6]
# ../keras/deneme/patient_file\ondort_resized_resized.jpg
# [26 27 28 ...  0  1  1]
# ../keras/deneme/patient_file\oniki_resized_resized.jpg
# [14 18 21 ... 27 14  6]
# ../keras/deneme/patient_file\onsekiz_resized_resized.jpg
# [ 9 20 38 ... 85 88 62]
# ../keras/deneme/patient_file\onuc_resized_resized.jpg
# [37 36 21 ...  6  6  6]
# ../keras/deneme/patient_file\onyedi_resized_resized.jpg
# [57 65 60 ... 23 24 25]
# ../keras/deneme/patient_file\on_resized_resized.jpg
# [ 1  5 12 ... 43 24 16]
# ../keras/deneme/patient_file\otuzalti_resized_resized.jpg
# [123 160 189 ...  61  73  49]
# ../keras/deneme/patient_file\otuzbes_resized_resized.jpg
# [48 49 53 ... 38 24  8]
# ../keras/deneme/patient_file\otuzbir_resized_resized.jpg
# [136 144 159 ... 152  98  37]
# ../keras/deneme/patient_file\otuzdokuz_resized_resized.jpg
# [ 3  9 39 ... 65 49 26]
# ../keras/deneme/patient_file\otuzdort_resized_resized.jpg
# [204 134 138 ...  89  74  77]
# ../keras/deneme/patient_file\otuziki_resized_resized.jpg
# [197 203 206 ...  47  30  13]
# ../keras/deneme/patient_file\otuzsekiz_resized_resized.jpg
# [36 48 49 ...  4  0  0]
# ../keras/deneme/patient_file\otuzuc_resized_resized.jpg
# [138 150 155 ... 124  92  95]
# ../keras/deneme/patient_file\otuzyedi_resized_resized.jpg
# [  3   0   0 ... 105  28   0]
# ../keras/deneme/patient_file\otuz_resized_resized.jpg
# [218 207 193 ... 150 131 180]
# ../keras/deneme/patient_file\sekiz_resized_resized.jpg
# [ 87 102 120 ...   5   4   2]
# ../keras/deneme/patient_file\seksenalti_resized_resized.jpg
# [ 0 18  0 ... 19 47 71]
# ../keras/deneme/patient_file\seksenbes_resized_resized.jpg
# [ 4  0  1 ... 66 32 15]
# ../keras/deneme/patient_file\seksenbir_resized_resized.jpg
# [161 182 191 ...  33  18  12]
# ../keras/deneme/patient_file\seksendort_resized_resized.jpg
# [  0   6   1 ... 156 159 167]
# ../keras/deneme/patient_file\sekseniki_resized_resized.jpg
# [ 19  37 148 ... 148 126 100]
# ../keras/deneme/patient_file\seksenuc_resized_resized.jpg
# [219 173 149 ... 100  74  59]
# ../keras/deneme/patient_file\seksenyedi_resized_resized.jpg
# [ 16  74 128 ... 121 128 109]
# ../keras/deneme/patient_file\seksen_resized_resized.jpg
# [ 7 16 26 ...  0  0  0]
# ../keras/deneme/patient_file\th10_resized_resized.jpg
# [10  0 25 ... 59 59 71]
# ../keras/deneme/patient_file\th11_resized_resized.jpg
# [ 76 107 112 ... 174 169 123]
# ../keras/deneme/patient_file\th12_resized_resized.jpg
# [ 99 107 119 ... 231 230 228]
# ../keras/deneme/patient_file\th13_resized_resized.jpg
# [ 60  37  54 ... 167 151 131]
# ../keras/deneme/patient_file\th14_resized_resized.jpg
# [ 82  95 104 ... 127 130 108]
# ../keras/deneme/patient_file\th15_resized_resized.jpg
# [32 45 67 ...  0  0  0]
# ../keras/deneme/patient_file\th1_resized_resized.jpg
# [232  85  70 ... 106 105 105]
# ../keras/deneme/patient_file\th2_resized_resized.jpg
# [24 21 29 ... 56 33 42]
# ../keras/deneme/patient_file\th3_resized_resized.jpg
# [ 48  70  77 ... 121 116  92]
# ../keras/deneme/patient_file\th4_resized_resized.jpg
# [ 87  94 110 ...  37  17  15]
# ../keras/deneme/patient_file\th5_resized_resized.jpg
# [137 141 183 ... 169 159 142]
# ../keras/deneme/patient_file\th6_resized_resized.jpg
# [30 30 49 ... 65 48 27]
# ../keras/deneme/patient_file\th7_resized_resized.jpg
# [148 175 167 ...  92  82 116]
# ../keras/deneme/patient_file\th8_resized_resized.jpg
# [18 17 20 ... 33 33 32]
# ../keras/deneme/patient_file\th9_resized_resized.jpg
# [220 239 238 ... 237 230 226]
# ../keras/deneme/patient_file\uc_resized_resized.jpg
# [  0   0   9 ... 149 134 121]
# ../keras/deneme/patient_file\UrolAnn_2018_10_4_409_239616_f1_resized_resized.jpg
# [ 83  94 101 ... 132 127 111]
# ../keras/deneme/patient_file\X-ray-KUB-of-a-patient-with-bilateral-renal-stones-Large-renal-shadows-seen_resized_resized.jpg
# [32 45 67 ...  0  0  0]
# ../keras/deneme/patient_file\yedi_resized_resized.jpg
# [156 168 179 ... 161 162 158]
# ../keras/deneme/patient_file\yetmisalti_resized_resized.jpg
# [24 53 89 ... 64 30 26]
# ../keras/deneme/patient_file\yetmisbes_resized_resized.jpg
# [173 196 202 ... 130 139  34]
# ../keras/deneme/patient_file\yetmisbir_resized_resized.jpg
# [  0   1   2 ... 134 126  28]
# ../keras/deneme/patient_file\yetmisdokuz_resized_resized.jpg
# [5 0 1 ... 2 2 2]
# ../keras/deneme/patient_file\yetmisdort_resized_resized.jpg
# [25 58 10 ... 18  7  1]
# ../keras/deneme/patient_file\yetmisiki_resized_resized.jpg
# [  0   3  62 ... 186 142  72]
# ../keras/deneme/patient_file\yetmissekiz_resized_resized.jpg
# [1 1 1 ... 0 6 2]
# ../keras/deneme/patient_file\yetmisuc_resized_resized.jpg
# [ 72 134 174 ...  42  20   0]
# ../keras/deneme/patient_file\yetmisyedi_resized_resized.jpg
# [  0   0   0 ... 115 106 129]
# ../keras/deneme/patient_file\yetmis_resized_resized.jpg
# [176 136 159 ...  75  49  40]
# ../keras/deneme/patient_file\yirmialti_resized_resized.jpg
# [ 72 101 120 ...  42  30  26]
# ../keras/deneme/patient_file\yirmibes_resized_resized.jpg
# [28 33 36 ... 96 82 63]
# ../keras/deneme/patient_file\yirmibir_resized_resized.jpg
# [ 2 32 76 ...  1  1  1]
# ../keras/deneme/patient_file\yirmidokuz_resized_resized.jpg
# [55 64 71 ... 77 50 40]
# ../keras/deneme/patient_file\yirmidort_resized_resized.jpg
# [32 57 78 ... 91 41 17]
# ../keras/deneme/patient_file\yirmiiki_resized_resized.jpg
# [ 1  2 23 ... 80 80 63]
# ../keras/deneme/patient_file\yirmisekiz_resized_resized.jpg
# [  8  64 152 ...  61  29  29]
# ../keras/deneme/patient_file\yirmiuc_resized_resized.jpg
# [174  89 124 ... 190 188 190]
# ../keras/deneme/patient_file\yirmiyedi_resized_resized.jpg
# [  9  23  36 ... 123 113  94]
# ../keras/deneme/patient_file\yirmi_resized_resized.jpg
# [ 6  3 28 ... 50 66 48]
# ../keras/deneme/patient_file\İMAGES 100_resized_resized.jpg
# [  0   0   1 ... 145 137 106]
# ../keras/deneme/patient_file\İMAGES 101_resized_resized.jpg
# [ 2  1  0 ... 78 71 56]
# ../keras/deneme/patient_file\İMAGES 11_resized_resized.jpg
# [122 145 172 ...  50  45  26]
# ../keras/deneme/patient_file\İMAGES 14_resized_resized.jpg
# [ 32  74 122 ...  88  98 107]
# ../keras/deneme/patient_file\İMAGES 15_resized_resized.jpg
# [ 0 25 50 ...  7  3  1]
# ../keras/deneme/patient_file\İMAGES 16_resized_resized.jpg
# [11 16 20 ... 33 28  9]
# ../keras/deneme/patient_file\İMAGES 17_resized_resized.jpg
# [ 9 53 92 ... 60 51 43]
# ../keras/deneme/patient_file\İMAGES 18_resized_resized.jpg
# [24 25 15 ... 32 13 16]
# ../keras/deneme/patient_file\İMAGES 19_resized_resized.jpg
# [ 5  0  4 ... 35 10  1]
# ../keras/deneme/patient_file\İMAGES 20_resized_resized.jpg
# [  0   9  10 ... 196 114  85]
# ../keras/deneme/patient_file\İMAGES 21_resized_resized.jpg
# [ 2  0  1 ... 81 84 98]
# ../keras/deneme/patient_file\İMAGES 23_resized_resized.jpg
# [79 72 74 ... 56 43 24]
# ../keras/deneme/patient_file\İMAGES 27_resized_resized.jpg
# [  0   4   2 ... 152 133  87]
# ../keras/deneme/patient_file\İMAGES 28_resized_resized.jpg
# [ 53  79  26 ... 176 125 123]
# ../keras/deneme/patient_file\İMAGES 29_resized_resized.jpg
# [  5   4   0 ... 169 171 144]
# ../keras/deneme/patient_file\İMAGES 31_resized_resized.jpg
# [16 23 28 ... 85  0  5]
# ../keras/deneme/patient_file\İMAGES 35_resized_resized.jpg
# [ 7 16 22 ... 85 62 35]
# ../keras/deneme/patient_file\İMAGES 36_resized_resized.jpg
# [16 24 30 ... 99 97 92]
# ../keras/deneme/patient_file\İMAGES 37_resized_resized.jpg
# [55 50 68 ...  6  1  0]
# ../keras/deneme/patient_file\İMAGES 39_resized_resized.jpg
# [34 35 36 ... 44 18 24]
# ../keras/deneme/patient_file\İMAGES 40_resized_resized.jpg
# [ 0  0  0 ... 14 20 17]
# ../keras/deneme/patient_file\İMAGES 43_resized_resized.jpg
# [ 1  6 38 ... 11 15  0]
# ../keras/deneme/patient_file\İMAGES 44_resized_resized.jpg
# [ 72 141 180 ...  92  80  52]
# ../keras/deneme/patient_file\İMAGES 45_resized_resized.jpg
# [  5  27  41 ... 105  71  69]
# ../keras/deneme/patient_file\İMAGES 47_resized_resized.jpg
# [  1   7   7 ... 142 126 113]
# ../keras/deneme/patient_file\İMAGES 48_resized_resized.jpg
# [19 23 23 ... 94 61 37]
# ../keras/deneme/patient_file\İMAGES 4_resized_resized.jpg
# [ 11   5   0 ... 103  99  93]
# ../keras/deneme/patient_file\İMAGES 51_resized_resized.jpg
# [ 10  18  20 ... 138 124  32]
# ../keras/deneme/patient_file\İMAGES 52_resized_resized.jpg
# [49 25 19 ... 52 28 13]
# ../keras/deneme/patient_file\İMAGES 53_resized_resized.jpg
# [52 33 27 ... 83 55 44]
# ../keras/deneme/patient_file\İMAGES 5_resized_resized.jpg
# [ 0  0 21 ...  2  0  0]
# ../keras/deneme/patient_file\İMAGES 61_resized_resized.jpg
# [ 5  0  6 ... 40 50 21]
# ../keras/deneme/patient_file\İMAGES 62_resized_resized.jpg
# [ 3  2  3 ... 65 79 72]
# ../keras/deneme/patient_file\İMAGES 65_resized_resized.jpg
# [ 0  0  0 ... 14 11  0]
# ../keras/deneme/patient_file\İMAGES 66_resized_resized.jpg
# [  3   0   2 ... 104 127  82]
# ../keras/deneme/patient_file\İMAGES 67_resized_resized.jpg
# [  2   1   8 ... 122  96  77]
# ../keras/deneme/patient_file\İMAGES 68_resized_resized.jpg
# [35 43 50 ... 84 55 64]
# ../keras/deneme/patient_file\İMAGES 69_resized_resized.jpg
# [3 3 6 ... 6 2 4]
# ../keras/deneme/patient_file\İMAGES 6_resized_resized.jpg
# [  3   3   0 ... 163 151  90]
# ../keras/deneme/patient_file\İMAGES 70_resized_resized.jpg
# [  0  14   8 ... 123 146 133]
# ../keras/deneme/patient_file\İMAGES 72_resized_resized.jpg
# [ 1 10 19 ... 86 56 50]
# ../keras/deneme/patient_file\İMAGES 74_resized_resized.jpg
# [ 45  75  68 ... 171 162 150]
# ../keras/deneme/patient_file\İMAGES 75_resized_resized.jpg
# [ 0  0  3 ... 94 83 50]
# ../keras/deneme/patient_file\İMAGES 76_resized_resized.jpg
# [  0   6   9 ... 127 139 105]
# ../keras/deneme/patient_file\İMAGES 77_resized_resized.jpg
# [  5   4   0 ... 169 171 144]
# ../keras/deneme/patient_file\İMAGES 78_resized_resized.jpg
# [  9  16   0 ... 109  93  69]
# ../keras/deneme/patient_file\İMAGES 79_resized_resized.jpg
# [ 53  79  26 ... 176 125 123]
# ../keras/deneme/patient_file\İMAGES 80_resized_resized.jpg
# [  0   4   2 ... 152 133  87]
# ../keras/deneme/patient_file\İMAGES 81_resized_resized.jpg
# [10 35 67 ... 10  9  3]
# ../keras/deneme/patient_file\İMAGES 82_resized_resized.jpg
# [ 62  74  86 ... 114  99  76]
# ../keras/deneme/patient_file\İMAGES 83_resized_resized.jpg
# [ 6 37 97 ... 40 32  7]
# ../keras/deneme/patient_file\İMAGES 84_resized_resized.jpg
# [ 1  3  6 ... 46 49 56]
# ../keras/deneme/patient_file\İMAGES 85_resized_resized.jpg
# [  5  27  61 ... 168 164 157]
# ../keras/deneme/patient_file\İMAGES 88_resized_resized.jpg
# [ 41  75 103 ...  77  75  70]
# ../keras/deneme/patient_file\İMAGES 89_resized_resized.jpg
# [36 24 78 ... 85 71 61]
# ../keras/deneme/patient_file\İMAGES 91_resized_resized.jpg
# [ 7  0 26 ... 76 60 40]
# ../keras/deneme/patient_file\İMAGES 92_resized_resized.jpg
# [154 176 194 ...   9   9  11]
# ../keras/deneme/patient_file\İMAGES 93_resized_resized.jpg
# [  2   0  19 ... 101  93  93]
# ../keras/deneme/patient_file\İMAGES 94_resized_resized.jpg
# [ 5  9 17 ... 49 31 25]
# ../keras/deneme/patient_file\İMAGES 95_resized_resized.jpg
# [191 191 173 ...  63 111 123]
# ../keras/deneme/patient_file\İMAGES 96_resized_resized.jpg
# [  4   1   9 ... 100  98  66]
# ../keras/deneme/patient_file\İMAGES 97_resized_resized.jpg
# [68 70 99 ... 39 41 53]
# ../keras/deneme/patient_file\İMAGES 98_resized_resized.jpg
# [26 33 36 ... 53 44 37]
# ../keras/deneme/patient_file\İMAGES 99_resized_resized.jpg
# [ 95  34  17 ... 145 146 147]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-631968201b4e> in <module>
#       3
#       4 # Create a graph for training
# ----> 5 logits_train = conv_net(X, N_CLASSES, dropout, reuse=False, is_training=True)
#       6 # Create another graph for testing that reuse the same weights
#       7 logits_test = conv_net(X, N_CLASSES, dropout, reuse=True, is_training=False)
#
# <ipython-input-92-659b8734abf1> in conv_net(x, n_classes, dropout, reuse, is_training)
#       5
#       6         # Convolution Layer with 32 filters and a kernel size of 5
# ----> 7         conv1 = tf.compat.v1.layers.conv2d(x, 32, 5, activation=tf.nn.relu)
#       8         # Max Pooling (down-sampling) with strides of 2 and kernel size of 2
#       9         conv1 = tf.layers.max_pooling2d(conv1, 2, 2)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\convolutional.py in conv2d(inputs, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, trainable, name, reuse)
#     422       _reuse=reuse,
#     423       _scope=name)
# --> 424   return layer.apply(inputs)
#     425
#     426
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py in apply(self, inputs, *args, **kwargs)
#    1699       Output tensor(s).
#    1700     """
# -> 1701     return self.__call__(inputs, *args, **kwargs)
#    1702
#    1703   @deprecation.deprecated(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\base.py in __call__(self, inputs, *args, **kwargs)
#     545
#     546       # Actually call layer
# --> 547       outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#     548
#     549     if not context.executing_eagerly():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py in __call__(self, *args, **kwargs)
#     755           # Build layer if applicable (if the `build` method has been
#     756           # overridden).
# --> 757           self._maybe_build(inputs)
#     758           cast_inputs = self._maybe_cast_inputs(inputs)
#     759
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py in _maybe_build(self, inputs)
#    2096         # operations.
#    2097         with tf_utils.maybe_init_scope(self):
# -> 2098           self.build(input_shapes)
#    2099       # We must set self.built since user defined build functions are not
#    2100       # constrained to set self.built.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\convolutional.py in build(self, input_shape)
#     195                                        self.filters)
#     196
# --> 197     self.kernel = self.add_weight(
#     198         name='kernel',
#     199         shape=kernel_shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\base.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, partitioner, **kwargs)
#     446         if initializer is None:
#     447           initializer = scope.initializer
# --> 448         variable = super(Layer, self).add_weight(
#     449             name,
#     450             shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     429         caching_device = None
#     430
# --> 431     variable = self._add_variable_with_custom_getter(
#     432         name=name,
#     433         shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     743         initializer = checkpoint_initializer
#     744         shape = None
# --> 745     new_variable = getter(
#     746         name=name,
#     747         shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1554                  synchronization=VariableSynchronization.AUTO,
#    1555                  aggregation=VariableAggregation.NONE):
# -> 1556   return get_variable_scope().get_variable(
#    1557       _get_default_variable_store(),
#    1558       name,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1297       if dtype is None:
#    1298         dtype = self._dtype
# -> 1299       return var_store.get_variable(
#    1300           full_name,
#    1301           shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#     552       return custom_getter(**custom_getter_kwargs)
#     553     else:
# --> 554       return _true_getter(
#     555           name,
#     556           shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint, synchronization, aggregation)
#     505             "name was already created with partitioning?" % name)
#     506
# --> 507       return self._get_single_variable(
#     508           name=name,
#     509           shape=shape,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint, synchronization, aggregation)
#     868         # default case.
#     869         tb = [x for x in tb if "tensorflow/python" not in x[0]][:5]
# --> 870         raise ValueError("%s Originally defined at:\n\n%s" %
#     871                          (err_msg, "".join(traceback.format_list(tb))))
#     872       found_var = self._vars[name]
#
# ValueError: Variable ConvNet/conv2d/kernel already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1949, in __init__
#     self._traceback = tf_stack.extract_stack()
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3477, in _create_op_internal
#     ret = Operation(
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 742, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\ops\gen_state_ops.py", line 1752, in variable_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\Isil\anaconda3\lib\site-packages\tensorflow\python\ops\state_ops.py", line 74, in variable_op_v2
#     return gen_state_ops.variable_v2(
